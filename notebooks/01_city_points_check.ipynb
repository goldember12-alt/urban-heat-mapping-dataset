# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from src.make_city_points import make_city_points

gdf = make_city_points()
gdf.head()
# Out:
#    city_id    city_name state climate_group      lat       lon  \
# 0        1      Phoenix    AZ      hot_arid  33.4484 -112.0740
# 1        2       Tucson    AZ      hot_arid  32.2226 -110.9747
# 2        3    Las Vegas    NV      hot_arid  36.1699 -115.1398
# 3        4  Albuquerque    NM      hot_arid  35.0844 -106.6504
# 4        5      El Paso    TX      hot_arid  31.7619 -106.4850
#
#                     geometry
# 0   POINT (-112.074 33.4484)
# 1  POINT (-110.9747 32.2226)
# 2  POINT (-115.1398 36.1699)
# 3  POINT (-106.6504 35.0844)
# 4   POINT (-106.485 31.7619)

# %%
import matplotlib.pyplot as plt

ax = gdf.plot(figsize=(10, 6), markersize=20)
ax.set_title("Study City Points")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
gdf.plot(ax=ax, markersize=20)
ax.set_title("Study City Points")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")

output_path = PROJECT_ROOT / "figures" / "study_city_points.png"
fig.savefig(output_path, dpi=300, bbox_inches="tight")
print(output_path)
# Out:
# C:\Users\golde\OneDrive\Documents\STAT5630_FinalProject_DataProcessing\figures\study_city_points.png
